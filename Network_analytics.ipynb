# %% [markdown]
# # Network Analytics

# %%
import pandas as pd
import networkx as nx

# %%
G = pd.read_csv("D:/Data Scientist/Network Analytics/Datasets/routes.csv")

# %%
G
# Out:
#        Unnamed: 0 Airline Airline ID Source Airport Source Airport ID  \
# 0               1      2B        410            AER              2965
# 1               2      2B        410            ASF              2966
# 2               3      2B        410            ASF              2966
# 3               4      2B        410            CEK              2968
# 4               5      2B        410            CEK              2968
# ...           ...     ...        ...            ...               ...
# 67658       67659      ZL       4178            WYA              6334
# 67659       67660      ZM      19016            DME              4029
# 67660       67661      ZM      19016            FRU              2912
# 67661       67662      ZM      19016            FRU              2912
# 67662       67663      ZM      19016            OSS              2913
#
#       Destination Airport Destination Airport ID Stops  Equipment   NA
# ...

# %%
G = G.iloc[0:100, 1:10]
G
# Out:
#    Airline Airline ID Source Airport Source Airport ID Destination Airport  \
# 0       2B        410            AER              2965                 KZN
# 1       2B        410            ASF              2966                 KZN
# 2       2B        410            ASF              2966                 MRV
# 3       2B        410            CEK              2968                 KZN
# 4       2B        410            CEK              2968                 OVB
# ..     ...        ...            ...               ...                 ...
# 95      2J        470            OUA               246                 ABJ
# 96      2J        470            OUA               246                 ACC
# 97      2J        470            OUA               246                 BKO
# 98      2J        470            OUA               246                 BOY
# 99      2J        470            OUA               246                 COO
#
#    Destination Airport ID Stops  Equipment           NA
# ...

# %%
G.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airline                 100 non-null    object
#  1   Airline ID              100 non-null    object
#  2   Source Airport          100 non-null    object
#  3   Source Airport ID       100 non-null    object
#  4   Destination Airport     100 non-null    object
#  5   Destination Airport ID  100 non-null    object
#  6   Stops                   0 non-null      object
#  7   Equipment               100 non-null    int64
#  8   NA                      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
g = nx.Graph()
g

# %%
g = nx.from_pandas_edgelist(G, source = 'Source Airport', target = 'Destination Airport')

# %%
print(g)
# Out:
# Graph with 43 nodes and 52 edges

# %%
# Degree Centrality
d = nx.degree_centrality(g)
print(d)
# Out:
# {'AER': 0.023809523809523808, 'KZN': 0.16666666666666666, 'ASF': 0.047619047619047616, 'MRV': 0.023809523809523808, 'CEK': 0.047619047619047616, 'OVB': 0.11904761904761904, 'DME': 0.09523809523809523, 'NBC': 0.09523809523809523, 'TGK': 0.023809523809523808, 'UUA': 0.07142857142857142, 'EGO': 0.047619047619047616, 'KGD': 0.023809523809523808, 'GYD': 0.023809523809523808, 'LED': 0.07142857142857142, 'SVX': 0.11904761904761904, 'NJC': 0.047619047619047616, 'NUX': 0.023809523809523808, 'BTK': 0.047619047619047616, 'IKT': 0.19047619047619047, 'HTA': 0.023809523809523808, 'KCK': 0.023809523809523808, 'ODO': 0.023809523809523808, 'UKX': 0.023809523809523808, 'ULK': 0.023809523809523808, 'YKS': 0.023809523809523808, 'MJZ': 0.023809523809523808, 'AYP': 0.023809523809523808, 'LIM': 0.11904761904761904, 'CUZ': 0.047619047619047616, 'PEM': 0.023809523809523808, 'HUU': 0.023809523809523808, 'IQT': 0.047619047619047616, 'PCL': 0.07142857142857142, 'TPP': 0.07142857142857142, 'ABJ': 0.0714285714285
# ...

# %%
pos = nx.spring_layout(g)
nx.draw_networkx(g, pos, node_size = 15, node_color = 'red')

# %%
# closeness centrality
closeness = nx.closeness_centrality(g)
print(closeness)
# Out:
# {'AER': 0.17928858290304076, 'KZN': 0.2522195318805488, 'ASF': 0.18371546149323925, 'MRV': 0.1417233560090703, 'CEK': 0.23620559334845048, 'OVB': 0.256568144499179, 'DME': 0.2010939510939511, 'NBC': 0.21566597653554176, 'TGK': 0.15184645286686102, 'UUA': 0.18147502903600465, 'EGO': 0.18371546149323925, 'KGD': 0.1417233560090703, 'GYD': 0.16001024065540193, 'LED': 0.19580200501253134, 'SVX': 0.27557319223985893, 'NJC': 0.20384866275277233, 'NUX': 0.1907814407814408, 'BTK': 0.1984126984126984, 'IKT': 0.21566597653554176, 'HTA': 0.16001024065540193, 'KCK': 0.16001024065540193, 'ODO': 0.16001024065540193, 'UKX': 0.16001024065540193, 'ULK': 0.16001024065540193, 'YKS': 0.16001024065540193, 'MJZ': 0.18147502903600465, 'AYP': 0.07777777777777778, 'LIM': 0.12962962962962962, 'CUZ': 0.08974358974358973, 'PEM': 0.06140350877192982, 'HUU': 0.07777777777777778, 'IQT': 0.06862745098039215, 'PCL': 0.09722222222222222, 'TPP': 0.09722222222222222, 'ABJ': 0.11721611721611722, 'BOY': 0.1088435374149659
# ...

# %%
## Betweeness Centrality 
b = nx.betweenness_centrality(g) # Betweeness_Centrality
print(b)
# Out:
# {'AER': 0.0, 'KZN': 0.16105303910181962, 'ASF': 0.027874564459930314, 'MRV': 0.0, 'CEK': 0.04645760743321719, 'OVB': 0.17886178861788618, 'DME': 0.03832752613240418, 'NBC': 0.04374758033294619, 'TGK': 0.0, 'UUA': 0.004258614014711576, 'EGO': 0.027874564459930314, 'KGD': 0.0, 'GYD': 0.0, 'LED': 0.010452961672473868, 'SVX': 0.148664343786295, 'NJC': 0.013937282229965157, 'NUX': 0.0, 'BTK': 0.0, 'IKT': 0.14982578397212543, 'HTA': 0.0, 'KCK': 0.0, 'ODO': 0.0, 'UKX': 0.0, 'ULK': 0.0, 'YKS': 0.0, 'MJZ': 0.0, 'AYP': 0.0, 'LIM': 0.019744483159117306, 'CUZ': 0.006968641114982578, 'PEM': 0.0, 'HUU': 0.0, 'IQT': 0.0, 'PCL': 0.0029036004645760743, 'TPP': 0.0029036004645760743, 'ABJ': 0.0005807200929152149, 'BOY': 0.0, 'OUA': 0.026713124274099883, 'ACC': 0.0, 'BKO': 0.0005807200929152149, 'DKR': 0.0, 'COO': 0.0, 'LFW': 0.0, 'NIM': 0.0}
